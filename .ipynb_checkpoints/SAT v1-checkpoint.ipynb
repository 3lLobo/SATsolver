# %%
import numpy as np
import pandas as pd

# %% [markdown]
# There are few ways we can encode the CNF variables and literals.
# 1. Any variable as x (which is already given in the DIMACS) and positive literals as 2x and negative literals as 2x+1. Benefits: bitwise operations. Downsides: I stole it.
# 2. List of tuples, where 0th element is the variable and 1st element is a binary variable that signifies if it's a positive or a negative.

# %%
#clause representation
clauses=[{1:0,2:1,3:0},[{4:1,2:0}]]
#variable representation
test_var = {1:[True, 0], 2: [False, 0,1,1], 3:[None, 0,1], 4:[None, 1,2,2] }

def transform_dict(l):
    new_dict = {}
    for element in l:
        if element[0]=="0": 
            break  
        elif element[0] == "-":
            key = int(element[1:])
        else:
            key = int(element)
        new_dict[key]=[]
    
    for element in l:
        if element[0]=="0": 
            break  
        elif element[0] == "-":
            new_dict[int(element[1:])].append(0)
        else:
            new_dict[int(element)].append(1)
    
    return new_dict

def transform_list(l):
    new_list = []
    for element in l:
        if element[0]=="-":
            new_list.append([int(element[1:]), 0])
        elif element[0]=="0": 
            continue  
        else:
            new_list.append([int(element[1:]), 1])
    return new_list

def read_dimac(file_name = "data/sudoku-rules.txt", num_var=1000, is_dict=True):
    #read file
    f = open(file_name, "r")
    lines = f.readlines()
    clauses={}
    #generate variables
    variables = {i: [None] for  i in range(num_var)}
    #for each clause
    for i, line in enumerate(lines):
        if i==0:
            continue
        
        if is_dict:
            clause = transform_dict(line.split())
            clauses[i] = clause
            for key in clause.keys():
                variables[key].append(i)
        else:
            clause = transform_list(line.split())
            clauses[i] = clause
            for element in clause:
                
                variables[element[0]].append(i)
    return clauses, variables
clauses, variables =read_dimac(is_dict=True)                       
clauses
# Out:
# {1: {111: [1],
#   112: [1],
#   113: [1],
#   114: [1],
#   115: [1],
#   116: [1],
#   117: [1],
#   118: [1],
#   119: [1]},
#  2: {111: [0], 112: [0]},
#  3: {111: [0], 113: [0]},
#  4: {111: [0], 114: [0]},
#  5: {111: [0], 115: [0]},
#  6: {111: [0], 116: [0]},
#  7: {111: [0], 117: [0]},
#  8: {111: [0], 118: [0]},
#  9: {111: [0], 119: [0]},
#  10: {112: [0], 113: [0]},
#  11: {112: [0], 114: [0]},
#  12: {112: [0], 115: [0]},
#  13: {112: [0], 116: [0]},
#  14: {112: [0], 117: [0]},
#  15: {112: [0], 118: [0]},
#  16: {112: [0], 119: [0]},
#  17: {113: [0], 114: [0]},
#  18: {113: [0], 115: [0]},
#  19: {113: [0], 116: [0]},
#  20: {113: [0], 117: [0]},
#  21: {113: [0], 118: [0]},
#  22: {113: [0], 119: [0]},
#  23: {114: [0], 115: [0]},
#  24: {114: [0], 116: [0]},
#  25: {114: [0], 117: [0]},
#  26: {114: [0], 118: [0]},
#  27: {114: [0], 119: [0]},
#  28: {115: [0], 116: [0]},
#  29: {115: [0], 117: [0]},
#  30: {115: [0], 118: [0]},
#  31: {115: [0], 119: [0]},
#  32: {116: [0], 117: [0]},
#  33: {116: [0], 118: [0]},
#  34: {116: [0], 119: [0]},
#  35: {117: [0], 118: [0]},
#  36: {117: [0], 119: [0]},
#  37: {118: [0], 119: [0]},
#  38: {121: [1],
#   122: [1],
#   123: [1],
#   124: [1],
#   125: [1],
#   126: [1],
#   127: [1],
#   128: [1],
#   129: [1]},
#  39: {121: [0], 122: [0]},
#  40: {121: [0], 123: [0]},
#  41: {121: [0], 124: [0]},
#  42: {121: [0], 125: [0]},
#  43: {121: [0], 126: [0]},
#  44: {121: [0], 127: [0]},
#  45: {121: [0], 128: [0]},
#  46: {121: [0], 129: [0]},
#  47: {122: [0], 123: [0]},
#  48: {122: [0], 124: [0]},
#  49: {122: [0], 125: [0]},
#  50: {122: [0], 126: [0]},
#  51: {122: [0], 127: [0]},
#  52: {122: [0], 128: [0]},
#  53: {122: [0], 129: [0]},
#  54: {123: [0], 124: [0]},
#  55: {123: [0], 125: [0]},
#  56: {123: [0], 126: [0]},
#  57: {123: [0], 127: [0]},
#  58: {123: [0], 128: [0]},
#  59: {123: [0], 129: [0]},
#  60: {124: [0], 125: [0]},
#  61: {124: [0], 126: [0]},
#  62: {124: [0], 127: [0]},
#  63: {124: [0], 128: [0]},
#  64: {124: [0], 129: [0]},
#  65: {125: [0], 126: [0]},
#  66: {125: [0], 127: [0]},
#  67: {125: [0], 128: [0]},
#  68: {125: [0], 129: [0]},
#  69: {126: [0], 127: [0]},
#  70: {126: [0], 128: [0]},
#  71: {126: [0], 129: [0]},
#  72: {127: [0], 128: [0]},
#  73: {127: [0], 129: [0]},
#  74: {128: [0], 129: [0]},
#  75: {131: [1],
#   132: [1],
#   133: [1],
#   134: [1],
#   135: [1],
#   136: [1],
#   137: [1],
#   138: [1],
#   139: [1]},
#  76: {131: [0], 132: [0]},
#  77: {131: [0], 133: [0]},
#  78: {131: [0], 134: [0]},
#  79: {131: [0], 135: [0]},
#  80: {131: [0], 136: [0]},
#  81: {131: [0], 137: [0]},
#  82: {131: [0], 138: [0]},
#  83: {131: [0], 139: [0]},
#  84: {132: [0], 133: [0]},
#  85: {132: [0], 134: [0]},
#  86: {132: [0], 135: [0]},
#  87: {132: [0], 136: [0]},
#  88: {132: [0], 137: [0]},
#  89: {132: [0], 138: [0]},
#  90: {132: [0], 139: [0]},
#  91: {133: [0], 134: [0]},
#  92: {133: [0], 135: [0]},
#  93: {133: [0], 136: [0]},
#  94: {133: [0], 137: [0]},
#  95: {133: [0], 138: [0]},
#  96: {133: [0], 139: [0]},
#  97: {134: [0], 135: [0]},
#  98: {134: [0], 136: [0]},
#  99: {134: [0], 137: [0]},
#  100: {134: [0], 138: [0]},
#  101: {134: [0], 139: [0]},
#  102: {135: [0], 136: [0]},
#  103: {135: [0], 137: [0]},
#  104: {135: [0], 138: [0]},
#  105: {135: [0], 139: [0]},
#  106: {136: [0], 137: [0]},
#  107: {136: [0], 138: [0]},
#  108: {136: [0], 139: [0]},
#  109: {137: [0], 138: [0]},
#  110: {137: [0], 139: [0]},
#  111: {138: [0], 139: [0]},
#  112: {141: [1],
#   142: [1],
#   143: [1],
#   144: [1],
#   145: [1],
#   146: [1],
#   147: [1],
#   148: [1],
#   149: [1]},
#  113: {141: [0], 142: [0]},
#  114: {141: [0], 143: [0]},
#  115: {141: [0], 144: [0]},
#  116: {141: [0], 145: [0]},
#  117: {141: [0], 146: [0]},
#  118: {141: [0], 147: [0]},
#  119: {141: [0], 148: [0]},
#  120: {141: [0], 149: [0]},
#  121: {142: [0], 143: [0]},
#  122: {142: [0], 144: [0]},
#  123: {142: [0], 145: [0]},
#  124: {142: [0], 146: [0]},
#  125: {142: [0], 147: [0]},
#  126: {142: [0], 148: [0]},
#  127: {142: [0], 149: [0]},
#  128: {143: [0], 144: [0]},
#  129: {143: [0], 145: [0]},
#  130: {143: [0], 146: [0]},
#  131: {143: [0], 147: [0]},
#  132: {143: [0], 148: [0]},
#  133: {143: [0], 149: [0]},
#  134: {144: [0], 145: [0]},
#  135: {144: [0], 146: [0]},
#  136: {144: [0], 147: [0]},
#  137: {144: [0], 148: [0]},
#  138: {144: [0], 149: [0]},
#  139: {145: [0], 146: [0]},
#  140: {145: [0], 147: [0]},
#  141: {145: [0], 148: [0]},
#  142: {145: [0], 149: [0]},
#  143: {146: [0], 147: [0]},
#  144: {146: [0], 148: [0]},
#  145: {146: [0], 149: [0]},
#  146: {147: [0], 148: [0]},
#  147: {147: [0], 149: [0]},
#  148: {148: [0], 149: [0]},
#  149: {151: [1],
#   152: [1],
#   153: [1],
#   154: [1],
#   155: [1],
#   156: [1],
#   157: [1],
#   158: [1],
#   159: [1]},
#  150: {151: [0], 152: [0]},
#  151: {151: [0], 153: [0]},
#  152: {151: [0], 154: [0]},
#  153: {151: [0], 155: [0]},
#  154: {151: [0], 156: [0]},
#  155: {151: [0], 157: [0]},
#  156: {151: [0], 158: [0]},
#  157: {151: [0], 159: [0]},
#  158: {152: [0], 153: [0]},
#  159: {152: [0], 154: [0]},
#  160: {152: [0], 155: [0]},
#  161: {152: [0], 156: [0]},
#  162: {152: [0], 157: [0]},
#  163: {152: [0], 158: [0]},
#  164: {152: [0], 159: [0]},
#  165: {153: [0], 154: [0]},
#  166: {153: [0], 155: [0]},
#  167: {153: [0], 156: [0]},
#  168: {153: [0], 157: [0]},
#  169: {153: [0], 158: [0]},
#  170: {153: [0], 159: [0]},
#  171: {154: [0], 155: [0]},
#  172: {154: [0], 156: [0]},
#  173: {154: [0], 157: [0]},
#  174: {154: [0], 158: [0]},
#  175: {154: [0], 159: [0]},
#  176: {155: [0], 156: [0]},
#  177: {155: [0], 157: [0]},
#  178: {155: [0], 158: [0]},
#  179: {155: [0], 159: [0]},
#  180: {156: [0], 157: [0]},
#  181: {156: [0], 158: [0]},
#  182: {156: [0], 159: [0]},
#  183: {157: [0], 158: [0]},
#  184: {157: [0], 159: [0]},
#  185: {158: [0], 159: [0]},
#  186: {161: [1],
#   162: [1],
#   163: [1],
#   164: [1],
#   165: [1],
#   166: [1],
#   167: [1],
#   168: [1],
#   169: [1]},
#  187: {161: [0], 162: [0]},
#  188: {161: [0], 163: [0]},
#  189: {161: [0], 164: [0]},
#  190: {161: [0], 165: [0]},
#  191: {161: [0], 166: [0]},
#  192: {161: [0], 167: [0]},
#  193: {161: [0], 168: [0]},
#  194: {161: [0], 169: [0]},
#  195: {162: [0], 163: [0]},
#  196: {162: [0], 164: [0]},
#  197: {162: [0], 165: [0]},
#  198: {162: [0], 166: [0]},
#  199: {162: [0], 167: [0]},
#  200: {162: [0], 168: [0]},
#  201: {162: [0], 169: [0]},
#  202: {163: [0], 164: [0]},
#  203: {163: [0], 165: [0]},
#  204: {163: [0], 166: [0]},
#  205: {163: [0], 167: [0]},
#  206: {163: [0], 168: [0]},
#  207: {163: [0], 169: [0]},
#  208: {164: [0], 165: [0]},
#  209: {164: [0], 166: [0]},
#  210: {164: [0], 167: [0]},
#  211: {164: [0], 168: [0]},
#  212: {164: [0], 169: [0]},
#  213: {165: [0], 166: [0]},
#  214: {165: [0], 167: [0]},
#  215: {165: [0], 168: [0]},
#  216: {165: [0], 169: [0]},
#  217: {166: [0], 167: [0]},
#  218: {166: [0], 168: [0]},
#  219: {166: [0], 169: [0]},
#  220: {167: [0], 168: [0]},
#  221: {167: [0], 169: [0]},
#  222: {168: [0], 169: [0]},
#  223: {171: [1],
#   172: [1],
#   173: [1],
#   174: [1],
#   175: [1],
#   176: [1],
#   177: [1],
#   178: [1],
#   179: [1]},
#  224: {171: [0], 172: [0]},
#  225: {171: [0], 173: [0]},
#  226: {171: [0], 174: [0]},
#  227: {171: [0], 175: [0]},
#  228: {171: [0], 176: [0]},
#  229: {171: [0], 177: [0]},
#  230: {171: [0], 178: [0]},
#  231: {171: [0], 179: [0]},
#  232: {172: [0], 173: [0]},
#  233: {172: [0], 174: [0]},
#  234: {172: [0], 175: [0]},
#  235: {172: [0], 176: [0]},
#  236: {172: [0], 177: [0]},
#  237: {172: [0], 178: [0]},
#  238: {172: [0], 179: [0]},
#  239: {173: [0], 174: [0]},
#  240: {173: [0], 175: [0]},
#  241: {173: [0], 176: [0]},
#  242: {173: [0], 177: [0]},
#  243: {173: [0], 178: [0]},
#  244: {173: [0], 179: [0]},
#  245: {174: [0], 175: [0]},
#  246: {174: [0], 176: [0]},
#  247: {174: [0], 177: [0]},
#  248: {174: [0], 178: [0]},
#  249: {174: [0], 179: [0]},
#  250: {175: [0], 176: [0]},
#  251: {175: [0], 177: [0]},
#  252: {175: [0], 178: [0]},
#  253: {175: [0], 179: [0]},
#  254: {176: [0], 177: [0]},
#  255: {176: [0], 178: [0]},
#  256: {176: [0], 179: [0]},
#  257: {177: [0], 178: [0]},
#  258: {177: [0], 179: [0]},
#  259: {178: [0], 179: [0]},
#  260: {181: [1],
#   182: [1],
#   183: [1],
#   184: [1],
#   185: [1],
#   186: [1],
#   187: [1],
#   188: [1],
#   189: [1]},
#  261: {181: [0], 182: [0]},
#  262: {181: [0], 183: [0]},
#  263: {181: [0], 184: [0]},
#  264: {181: [0], 185: [0]},
#  265: {181: [0], 186: [0]},
#  266: {181: [0], 187: [0]},
#  267: {181: [0], 188: [0]},
#  268: {181: [0], 189: [0]},
#  269: {182: [0], 183: [0]},
#  270: {182: [0], 184: [0]},
#  271: {182: [0], 185: [0]},
#  272: {182: [0], 186: [0]},
#  273: {182: [0], 187: [0]},
#  274: {182: [0], 188: [0]},
#  275: {182: [0], 189: [0]},
#  276: {183: [0], 184: [0]},
#  277: {183: [0], 185: [0]},
#  278: {183: [0], 186: [0]},
#  279: {183: [0], 187: [0]},
#  280: {183: [0], 188: [0]},
#  281: {183: [0], 189: [0]},
#  282: {184: [0], 185: [0]},
#  283: {184: [0], 186: [0]},
#  284: {184: [0], 187: [0]},
#  285: {184: [0], 188: [0]},
#  286: {184: [0], 189: [0]},
#  287: {185: [0], 186: [0]},
#  288: {185: [0], 187: [0]},
#  289: {185: [0], 188: [0]},
#  290: {185: [0], 189: [0]},
#  291: {186: [0], 187: [0]},
#  292: {186: [0], 188: [0]},
#  293: {186: [0], 189: [0]},
#  294: {187: [0], 188: [0]},
#  295: {187: [0], 189: [0]},
#  296: {188: [0], 189: [0]},
#  297: {191: [1],
#   192: [1],
#   193: [1],
#   194: [1],
#   195: [1],
#   196: [1],
#   197: [1],
#   198: [1],
#   199: [1]},
#  298: {191: [0], 192: [0]},
#  299: {191: [0], 193: [0]},
#  300: {191: [0], 194: [0]},
#  301: {191: [0], 195: [0]},
#  302: {191: [0], 196: [0]},
#  303: {191: [0], 197: [0]},
#  304: {191: [0], 198: [0]},
#  305: {191: [0], 199: [0]},
#  306: {192: [0], 193: [0]},
#  307: {192: [0], 194: [0]},
#  308: {192: [0], 195: [0]},
#  309: {192: [0], 196: [0]},
#  310: {192: [0], 197: [0]},
#  311: {192: [0], 198: [0]},
#  312: {192: [0], 199: [0]},
#  313: {193: [0], 194: [0]},
#  314: {193: [0], 195: [0]},
#  315: {193: [0], 196: [0]},
#  316: {193: [0], 197: [0]},
#  317: {193: [0], 198: [0]},
#  318: {193: [0], 199: [0]},
#  319: {194: [0], 195: [0]},
#  320: {194: [0], 196: [0]},
#  321: {194: [0], 197: [0]},
#  322: {194: [0], 198: [0]},
#  323: {194: [0], 199: [0]},
#  324: {195: [0], 196: [0]},
#  325: {195: [0], 197: [0]},
#  326: {195: [0], 198: [0]},
#  327: {195: [0], 199: [0]},
#  328: {196: [0], 197: [0]},
#  329: {196: [0], 198: [0]},
#  330: {196: [0], 199: [0]},
#  331: {197: [0], 198: [0]},
#  332: {197: [0], 199: [0]},
#  333: {198: [0], 199: [0]},
#  334: {211: [1],
#   212: [1],
#   213: [1],
#   214: [1],
#   215: [1],
#   216: [1],
#   217: [1],
#   218: [1],
#   219: [1]},
#  335: {211: [0], 212: [0]},
#  336: {211: [0], 213: [0]},
#  337: {211: [0], 214: [0]},
#  338: {211: [0], 215: [0]},
#  339: {211: [0], 216: [0]},
#  340: {211: [0], 217: [0]},
#  341: {211: [0], 218: [0]},
#  342: {211: [0], 219: [0]},
#  343: {212: [0], 213: [0]},
#  344: {212: [0], 214: [0]},
#  345: {212: [0], 215: [0]},
#  346: {212: [0], 216: [0]},
#  347: {212: [0], 217: [0]},
#  348: {212: [0], 218: [0]},
#  349: {212: [0], 219: [0]},
#  350: {213: [0], 214: [0]},
#  351: {213: [0], 215: [0]},
#  352: {213: [0], 216: [0]},
#  353: {213: [0], 217: [0]},
#  354: {213: [0], 218: [0]},
#  355: {213: [0], 219: [0]},
#  356: {214: [0], 215: [0]},
#  357: {214: [0], 216: [0]},
#  358: {214: [0], 217: [0]},
#  359: {214: [0], 218: [0]},
#  360: {214: [0], 219: [0]},
#  361: {215: [0], 216: [0]},
#  362: {215: [0], 217: [0]},
#  363: {215: [0], 218: [0]},
#  364: {215: [0], 219: [0]},
#  365: {216: [0], 217: [0]},
#  366: {216: [0], 218: [0]},
#  367: {216: [0], 219: [0]},
#  368: {217: [0], 218: [0]},
#  369: {217: [0], 219: [0]},
#  370: {218: [0], 219: [0]},
#  371: {221: [1],
#   222: [1],
#   223: [1],
#   224: [1],
#   225: [1],
#   226: [1],
#   227: [1],
#   228: [1],
#   229: [1]},
#  372: {221: [0], 222: [0]},
#  373: {221: [0], 223: [0]},
#  374: {221: [0], 224: [0]},
#  375: {221: [0], 225: [0]},
#  376: {221: [0], 226: [0]},
#  377: {221: [0], 227: [0]},
#  378: {221: [0], 228: [0]},
#  379: {221: [0], 229: [0]},
#  380: {222: [0], 223: [0]},
#  381: {222: [0], 224: [0]},
#  382: {222: [0], 225: [0]},
#  383: {222: [0], 226: [0]},
#  384: {222: [0], 227: [0]},
#  385: {222: [0], 228: [0]},
#  386: {222: [0], 229: [0]},
#  387: {223: [0], 224: [0]},
#  388: {223: [0], 225: [0]},
#  389: {223: [0], 226: [0]},
#  390: {223: [0], 227: [0]},
#  391: {223: [0], 228: [0]},
#  392: {223: [0], 229: [0]},
#  393: {224: [0], 225: [0]},
#  394: {224: [0], 226: [0]},
#  395: {224: [0], 227: [0]},
#  396: {224: [0], 228: [0]},
#  397: {224: [0], 229: [0]},
#  398: {225: [0], 226: [0]},
#  399: {225: [0], 227: [0]},
#  400: {225: [0], 228: [0]},
#  401: {225: [0], 229: [0]},
#  402: {226: [0], 227: [0]},
#  403: {226: [0], 228: [0]},
#  404: {226: [0], 229: [0]},
#  405: {227: [0], 228: [0]},
#  406: {227: [0], 229: [0]},
#  407: {228: [0], 229: [0]},
#  408: {231: [1],
#   232: [1],
#   233: [1],
#   234: [1],
#   235: [1],
#   236: [1],
#   237: [1],
#   238: [1],
#   239: [1]},
#  409: {231: [0], 232: [0]},
#  410: {231: [0], 233: [0]},
#  411: {231: [0], 234: [0]},
#  412: {231: [0], 235: [0]},
#  413: {231: [0], 236: [0]},
#  414: {231: [0], 237: [0]},
#  415: {231: [0], 238: [0]},
#  416: {231: [0], 239: [0]},
#  417: {232: [0], 233: [0]},
#  418: {232: [0], 234: [0]},
#  419: {232: [0], 235: [0]},
#  420: {232: [0], 236: [0]},
#  421: {232: [0], 237: [0]},
#  422: {232: [0], 238: [0]},
#  423: {232: [0], 239: [0]},
#  424: {233: [0], 234: [0]},
#  425: {233: [0], 235: [0]},
#  426: {233: [0], 236: [0]},
#  427: {233: [0], 237: [0]},
#  428: {233: [0], 238: [0]},
#  429: {233: [0], 239: [0]},
#  430: {234: [0], 235: [0]},
#  431: {234: [0], 236: [0]},
#  432: {234: [0], 237: [0]},
#  433: {234: [0], 238: [0]},
#  434: {234: [0], 239: [0]},
#  435: {235: [0], 236: [0]},
#  436: {235: [0], 237: [0]},
#  437: {235: [0], 238: [0]},
#  438: {235: [0], 239: [0]},
#  439: {236: [0], 237: [0]},
#  440: {236: [0], 238: [0]},
#  441: {236: [0], 239: [0]},
#  442: {237: [0], 238: [0]},
#  443: {237: [0], 239: [0]},
#  444: {238: [0], 239: [0]},
#  445: {241: [1],
#   242: [1],
#   243: [1],
#   244: [1],
#   245: [1],
#   246: [1],
#   247: [1],
#   248: [1],
#   249: [1]},
#  446: {241: [0], 242: [0]},
#  447: {241: [0], 243: [0]},
#  448: {241: [0], 244: [0]},
#  449: {241: [0], 245: [0]},
#  450: {241: [0], 246: [0]},
#  451: {241: [0], 247: [0]},
#  452: {241: [0], 248: [0]},
#  453: {241: [0], 249: [0]},
#  454: {242: [0], 243: [0]},
#  455: {242: [0], 244: [0]},
#  456: {242: [0], 245: [0]},
#  457: {242: [0], 246: [0]},
#  458: {242: [0], 247: [0]},
#  459: {242: [0], 248: [0]},
#  460: {242: [0], 249: [0]},
#  461: {243: [0], 244: [0]},
#  462: {243: [0], 245: [0]},
#  463: {243: [0], 246: [0]},
#  464: {243: [0], 247: [0]},
#  465: {243: [0], 248: [0]},
#  466: {243: [0], 249: [0]},
#  467: {244: [0], 245: [0]},
#  468: {244: [0], 246: [0]},
#  469: {244: [0], 247: [0]},
#  470: {244: [0], 248: [0]},
#  471: {244: [0], 249: [0]},
#  472: {245: [0], 246: [0]},
#  473: {245: [0], 247: [0]},
#  474: {245: [0], 248: [0]},
#  475: {245: [0], 249: [0]},
#  476: {246: [0], 247: [0]},
#  477: {246: [0], 248: [0]},
#  478: {246: [0], 249: [0]},
#  479: {247: [0], 248: [0]},
#  480: {247: [0], 249: [0]},
#  481: {248: [0], 249: [0]},
#  482: {251: [1],
#   252: [1],
#   253: [1],
#   254: [1],
#   255: [1],
#   256: [1],
#   257: [1],
#   258: [1],
#   259: [1]},
#  483: {251: [0], 252: [0]},
#  484: {251: [0], 253: [0]},
#  485: {251: [0], 254: [0]},
#  486: {251: [0], 255: [0]},
#  487: {251: [0], 256: [0]},
#  488: {251: [0], 257: [0]},
#  489: {251: [0], 258: [0]},
#  490: {251: [0], 259: [0]},
#  491: {252: [0], 253: [0]},
#  492: {252: [0], 254: [0]},
#  493: {252: [0], 255: [0]},
#  494: {252: [0], 256: [0]},
#  495: {252: [0], 257: [0]},
#  496: {252: [0], 258: [0]},
#  497: {252: [0], 259: [0]},
#  498: {253: [0], 254: [0]},
#  499: {253: [0], 255: [0]},
#  500: {253: [0], 256: [0]},
#  501: {253: [0], 257: [0]},
#  502: {253: [0], 258: [0]},
#  503: {253: [0], 259: [0]},
#  504: {254: [0], 255: [0]},
#  505: {254: [0], 256: [0]},
#  506: {254: [0], 257: [0]},
#  507: {254: [0], 258: [0]},
#  508: {254: [0], 259: [0]},
#  509: {255: [0], 256: [0]},
#  510: {255: [0], 257: [0]},
#  511: {255: [0], 258: [0]},
#  512: {255: [0], 259: [0]},
#  513: {256: [0], 257: [0]},
#  514: {256: [0], 258: [0]},
#  515: {256: [0], 259: [0]},
#  516: {257: [0], 258: [0]},
#  517: {257: [0], 259: [0]},
#  518: {258: [0], 259: [0]},
#  519: {261: [1],
#   262: [1],
#   263: [1],
#   264: [1],
#   265: [1],
#   266: [1],
#   267: [1],
#   268: [1],
#   269: [1]},
#  520: {261: [0], 262: [0]},
#  521: {261: [0], 263: [0]},
#  522: {261: [0], 264: [0]},
#  523: {261: [0], 265: [0]},
#  524: {261: [0], 266: [0]},
#  525: {261: [0], 267: [0]},
#  526: {261: [0], 268: [0]},
#  527: {261: [0], 269: [0]},
#  528: {262: [0], 263: [0]},
#  529: {262: [0], 264: [0]},
#  530: {262: [0], 265: [0]},
#  531: {262: [0], 266: [0]},
#  532: {262: [0], 267: [0]},
#  533: {262: [0], 268: [0]},
#  534: {262: [0], 269: [0]},
#  535: {263: [0], 264: [0]},
#  536: {263: [0], 265: [0]},
#  537: {263: [0], 266: [0]},
#  538: {263: [0], 267: [0]},
#  539: {263: [0], 268: [0]},
#  540: {263: [0], 269: [0]},
#  541: {264: [0], 265: [0]},
#  542: {264: [0], 266: [0]},
#  543: {264: [0], 267: [0]},
#  544: {264: [0], 268: [0]},
#  545: {264: [0], 269: [0]},
#  546: {265: [0], 266: [0]},
#  547: {265: [0], 267: [0]},
#  548: {265: [0], 268: [0]},
#  549: {265: [0], 269: [0]},
#  550: {266: [0], 267: [0]},
#  551: {266: [0], 268: [0]},
#  552: {266: [0], 269: [0]},
#  553: {267: [0], 268: [0]},
#  554: {267: [0], 269: [0]},
#  555: {268: [0], 269: [0]},
#  556: {271: [1],
#   272: [1],
#   273: [1],
#   274: [1],
#   275: [1],
#   276: [1],
#   277: [1],
#   278: [1],
#   279: [1]},
#  557: {271: [0], 272: [0]},
#  558: {271: [0], 273: [0]},
#  559: {271: [0], 274: [0]},
#  560: {271: [0], 275: [0]},
#  561: {271: [0], 276: [0]},
#  562: {271: [0], 277: [0]},
#  563: {271: [0], 278: [0]},
#  564: {271: [0], 279: [0]},
#  565: {272: [0], 273: [0]},
#  566: {272: [0], 274: [0]},
#  567: {272: [0], 275: [0]},
#  568: {272: [0], 276: [0]},
#  569: {272: [0], 277: [0]},
#  570: {272: [0], 278: [0]},
#  571: {272: [0], 279: [0]},
#  572: {273: [0], 274: [0]},
#  573: {273: [0], 275: [0]},
#  574: {273: [0], 276: [0]},
#  575: {273: [0], 277: [0]},
#  576: {273: [0], 278: [0]},
#  577: {273: [0], 279: [0]},
#  578: {274: [0], 275: [0]},
#  579: {274: [0], 276: [0]},
#  580: {274: [0], 277: [0]},
#  581: {274: [0], 278: [0]},
#  582: {274: [0], 279: [0]},
#  583: {275: [0], 276: [0]},
#  584: {275: [0], 277: [0]},
#  585: {275: [0], 278: [0]},
#  586: {275: [0], 279: [0]},
#  587: {276: [0], 277: [0]},
#  588: {276: [0], 278: [0]},
#  589: {276: [0], 279: [0]},
#  590: {277: [0], 278: [0]},
#  591: {277: [0], 279: [0]},
#  592: {278: [0], 279: [0]},
#  593: {281: [1],
#   282: [1],
#   283: [1],
#   284: [1],
#   285: [1],
#   286: [1],
#   287: [1],
#   288: [1],
#   289: [1]},
#  594: {281: [0], 282: [0]},
#  595: {281: [0], 283: [0]},
#  596: {281: [0], 284: [0]},
#  597: {281: [0], 285: [0]},
#  598: {281: [0], 286: [0]},
#  599: {281: [0], 287: [0]},
#  600: {281: [0], 288: [0]},
#  601: {281: [0], 289: [0]},
#  602: {282: [0], 283: [0]},
#  603: {282: [0], 284: [0]},
#  604: {282: [0], 285: [0]},
#  605: {282: [0], 286: [0]},
#  606: {282: [0], 287: [0]},
#  607: {282: [0], 288: [0]},
#  608: {282: [0], 289: [0]},
#  609: {283: [0], 284: [0]},
#  610: {283: [0], 285: [0]},
#  611: {283: [0], 286: [0]},
#  612: {283: [0], 287: [0]},
#  613: {283: [0], 288: [0]},
#  614: {283: [0], 289: [0]},
#  615: {284: [0], 285: [0]},
#  616: {284: [0], 286: [0]},
#  617: {284: [0], 287: [0]},
#  618: {284: [0], 288: [0]},
#  619: {284: [0], 289: [0]},
#  620: {285: [0], 286: [0]},
#  621: {285: [0], 287: [0]},
#  622: {285: [0], 288: [0]},
#  623: {285: [0], 289: [0]},
#  624: {286: [0], 287: [0]},
#  625: {286: [0], 288: [0]},
#  626: {286: [0], 289: [0]},
#  627: {287: [0], 288: [0]},
#  628: {287: [0], 289: [0]},
#  629: {288: [0], 289: [0]},
#  630: {291: [1],
#   292: [1],
#   293: [1],
#   294: [1],
#   295: [1],
#   296: [1],
#   297: [1],
#   298: [1],
#   299: [1]},
#  631: {291: [0], 292: [0]},
#  632: {291: [0], 293: [0]},
#  633: {291: [0], 294: [0]},
#  634: {291: [0], 295: [0]},
#  635: {291: [0], 296: [0]},
#  636: {291: [0], 297: [0]},
#  637: {291: [0], 298: [0]},
#  638: {291: [0], 299: [0]},
#  639: {292: [0], 293: [0]},
#  640: {292: [0], 294: [0]},
#  641: {292: [0], 295: [0]},
#  642: {292: [0], 296: [0]},
#  643: {292: [0], 297: [0]},
#  644: {292: [0], 298: [0]},
#  645: {292: [0], 299: [0]},
#  646: {293: [0], 294: [0]},
#  647: {293: [0], 295: [0]},
#  648: {293: [0], 296: [0]},
#  649: {293: [0], 297: [0]},
#  650: {293: [0], 298: [0]},
#  651: {293: [0], 299: [0]},
#  652: {294: [0], 295: [0]},
#  653: {294: [0], 296: [0]},
#  654: {294: [0], 297: [0]},
#  655: {294: [0], 298: [0]},
#  656: {294: [0], 299: [0]},
#  657: {295: [0], 296: [0]},
#  658: {295: [0], 297: [0]},
#  659: {295: [0], 298: [0]},
#  660: {295: [0], 299: [0]},
#  661: {296: [0], 297: [0]},
#  662: {296: [0], 298: [0]},
#  663: {296: [0], 299: [0]},
#  664: {297: [0], 298: [0]},
#  665: {297: [0], 299: [0]},
#  666: {298: [0], 299: [0]},
#  667: {311: [1],
#   312: [1],
#   313: [1],
#   314: [1],
#   315: [1],
#   316: [1],
#   317: [1],
#   318: [1],
#   319: [1]},
#  668: {311: [0], 312: [0]},
#  669: {311: [0], 313: [0]},
#  670: {311: [0], 314: [0]},
#  671: {311: [0], 315: [0]},
#  672: {311: [0], 316: [0]},
#  673: {311: [0], 317: [0]},
#  674: {311: [0], 318: [0]},
#  675: {311: [0], 319: [0]},
#  676: {312: [0], 313: [0]},
#  677: {312: [0], 314: [0]},
#  678: {312: [0], 315: [0]},
#  679: {312: [0], 316: [0]},
#  680: {312: [0], 317: [0]},
#  681: {312: [0], 318: [0]},
#  682: {312: [0], 319: [0]},
#  683: {313: [0], 314: [0]},
#  684: {313: [0], 315: [0]},
#  685: {313: [0], 316: [0]},
#  686: {313: [0], 317: [0]},
#  687: {313: [0], 318: [0]},
#  688: {313: [0], 319: [0]},
#  689: {314: [0], 315: [0]},
#  690: {314: [0], 316: [0]},
#  691: {314: [0], 317: [0]},
#  692: {314: [0], 318: [0]},
#  693: {314: [0], 319: [0]},
#  694: {315: [0], 316: [0]},
#  695: {315: [0], 317: [0]},
#  696: {315: [0], 318: [0]},
#  697: {315: [0], 319: [0]},
#  698: {316: [0], 317: [0]},
#  699: {316: [0], 318: [0]},
#  700: {316: [0], 319: [0]},
#  701: {317: [0], 318: [0]},
#  702: {317: [0], 319: [0]},
#  703: {318: [0], 319: [0]},
#  704: {321: [1],
#   322: [1],
#   323: [1],
#   324: [1],
#   325: [1],
#   326: [1],
#   327: [1],
#   328: [1],
#   329: [1]},
#  705: {321: [0], 322: [0]},
#  706: {321: [0], 323: [0]},
#  707: {321: [0], 324: [0]},
#  708: {321: [0], 325: [0]},
#  709: {321: [0], 326: [0]},
#  710: {321: [0], 327: [0]},
#  711: {321: [0], 328: [0]},
#  712: {321: [0], 329: [0]},
#  713: {322: [0], 323: [0]},
#  714: {322: [0], 324: [0]},
#  715: {322: [0], 325: [0]},
#  716: {322: [0], 326: [0]},
#  717: {322: [0], 327: [0]},
#  718: {322: [0], 328: [0]},
#  719: {322: [0], 329: [0]},
#  720: {323: [0], 324: [0]},
#  721: {323: [0], 325: [0]},
#  722: {323: [0], 326: [0]},
#  723: {323: [0], 327: [0]},
#  724: {323: [0], 328: [0]},
#  725: {323: [0], 329: [0]},
#  726: {324: [0], 325: [0]},
#  727: {324: [0], 326: [0]},
#  728: {324: [0], 327: [0]},
#  729: {324: [0], 328: [0]},
#  730: {324: [0], 329: [0]},
#  731: {325: [0], 326: [0]},
#  732: {325: [0], 327: [0]},
#  733: {325: [0], 328: [0]},
#  734: {325: [0], 329: [0]},
#  735: {326: [0], 327: [0]},
#  736: {326: [0], 328: [0]},
#  737: {326: [0], 329: [0]},
#  738: {327: [0], 328: [0]},
#  739: {327: [0], 329: [0]},
#  740: {328: [0], 329: [0]},
#  741: {331: [1],
#   332: [1],
#   333: [1],
#   334: [1],
#   335: [1],
#   336: [1],
#   337: [1],
#   338: [1],
#   339: [1]},
#  742: {331: [0], 332: [0]},
#  743: {331: [0], 333: [0]},
#  744: {331: [0], 334: [0]},
#  745: {331: [0], 335: [0]},
#  746: {331: [0], 336: [0]},
#  747: {331: [0], 337: [0]},
#  748: {331: [0], 338: [0]},
#  749: {331: [0], 339: [0]},
#  750: {332: [0], 333: [0]},
#  751: {332: [0], 334: [0]},
#  752: {332: [0], 335: [0]},
#  753: {332: [0], 336: [0]},
#  754: {332: [0], 337: [0]},
#  755: {332: [0], 338: [0]},
#  756: {332: [0], 339: [0]},
#  757: {333: [0], 334: [0]},
#  758: {333: [0], 335: [0]},
#  759: {333: [0], 336: [0]},
#  760: {333: [0], 337: [0]},
#  761: {333: [0], 338: [0]},
#  762: {333: [0], 339: [0]},
#  763: {334: [0], 335: [0]},
#  764: {334: [0], 336: [0]},
#  765: {334: [0], 337: [0]},
#  766: {334: [0], 338: [0]},
#  767: {334: [0], 339: [0]},
#  768: {335: [0], 336: [0]},
#  769: {335: [0], 337: [0]},
#  770: {335: [0], 338: [0]},
#  771: {335: [0], 339: [0]},
#  772: {336: [0], 337: [0]},
#  773: {336: [0], 338: [0]},
#  774: {336: [0], 339: [0]},
#  775: {337: [0], 338: [0]},
#  776: {337: [0], 339: [0]},
#  777: {338: [0], 339: [0]},
#  778: {341: [1],
#   342: [1],
#   343: [1],
#   344: [1],
#   345: [1],
#   346: [1],
#   347: [1],
#   348: [1],
#   349: [1]},
#  779: {341: [0], 342: [0]},
#  780: {341: [0], 343: [0]},
#  781: {341: [0], 344: [0]},
#  782: {341: [0], 345: [0]},
#  783: {341: [0], 346: [0]},
#  784: {341: [0], 347: [0]},
#  785: {341: [0], 348: [0]},
#  786: {341: [0], 349: [0]},
#  787: {342: [0], 343: [0]},
#  788: {342: [0], 344: [0]},
#  789: {342: [0], 345: [0]},
#  790: {342: [0], 346: [0]},
#  791: {342: [0], 347: [0]},
#  792: {342: [0], 348: [0]},
#  793: {342: [0], 349: [0]},
#  794: {343: [0], 344: [0]},
#  795: {343: [0], 345: [0]},
#  796: {343: [0], 346: [0]},
#  797: {343: [0], 347: [0]},
#  798: {343: [0], 348: [0]},
#  799: {343: [0], 349: [0]},
#  800: {344: [0], 345: [0]},
#  801: {344: [0], 346: [0]},
#  802: {344: [0], 347: [0]},
#  803: {344: [0], 348: [0]},
#  804: {344: [0], 349: [0]},
#  805: {345: [0], 346: [0]},
#  806: {345: [0], 347: [0]},
#  807: {345: [0], 348: [0]},
#  808: {345: [0], 349: [0]},
#  809: {346: [0], 347: [0]},
#  810: {346: [0], 348: [0]},
#  811: {346: [0], 349: [0]},
#  812: {347: [0], 348: [0]},
#  813: {347: [0], 349: [0]},
#  814: {348: [0], 349: [0]},
#  815: {351: [1],
#   352: [1],
#   353: [1],
#   354: [1],
#   355: [1],
#   356: [1],
#   357: [1],
#   358: [1],
#   359: [1]},
#  816: {351: [0], 352: [0]},
#  817: {351: [0], 353: [0]},
#  818: {351: [0], 354: [0]},
#  819: {351: [0], 355: [0]},
#  820: {351: [0], 356: [0]},
#  821: {351: [0], 357: [0]},
#  822: {351: [0], 358: [0]},
#  823: {351: [0], 359: [0]},
#  824: {352: [0], 353: [0]},
#  825: {352: [0], 354: [0]},
#  826: {352: [0], 355: [0]},
#  827: {352: [0], 356: [0]},
#  828: {352: [0], 357: [0]},
#  829: {352: [0], 358: [0]},
#  830: {352: [0], 359: [0]},
#  831: {353: [0], 354: [0]},
#  832: {353: [0], 355: [0]},
#  833: {353: [0], 356: [0]},
#  834: {353: [0], 357: [0]},
#  835: {353: [0], 358: [0]},
#  836: {353: [0], 359: [0]},
#  837: {354: [0], 355: [0]},
#  838: {354: [0], 356: [0]},
#  839: {354: [0], 357: [0]},
#  840: {354: [0], 358: [0]},
#  841: {354: [0], 359: [0]},
#  842: {355: [0], 356: [0]},
#  843: {355: [0], 357: [0]},
#  844: {355: [0], 358: [0]},
#  845: {355: [0], 359: [0]},
#  846: {356: [0], 357: [0]},
#  847: {356: [0], 358: [0]},
#  848: {356: [0], 359: [0]},
#  849: {357: [0], 358: [0]},
#  850: {357: [0], 359: [0]},
#  851: {358: [0], 359: [0]},
#  852: {361: [1],
#   362: [1],
#   363: [1],
#   364: [1],
#   365: [1],
#   366: [1],
#   367: [1],
#   368: [1],
#   369: [1]},
#  853: {361: [0], 362: [0]},
#  854: {361: [0], 363: [0]},
#  855: {361: [0], 364: [0]},
#  856: {361: [0], 365: [0]},
#  857: {361: [0], 366: [0]},
#  858: {361: [0], 367: [0]},
#  859: {361: [0], 368: [0]},
#  860: {361: [0], 369: [0]},
#  861: {362: [0], 363: [0]},
#  862: {362: [0], 364: [0]},
#  863: {362: [0], 365: [0]},
#  864: {362: [0], 366: [0]},
#  865: {362: [0], 367: [0]},
#  866: {362: [0], 368: [0]},
#  867: {362: [0], 369: [0]},
#  868: {363: [0], 364: [0]},
#  869: {363: [0], 365: [0]},
#  870: {363: [0], 366: [0]},
#  871: {363: [0], 367: [0]},
#  872: {363: [0], 368: [0]},
#  873: {363: [0], 369: [0]},
#  874: {364: [0], 365: [0]},
#  875: {364: [0], 366: [0]},
#  876: {364: [0], 367: [0]},
#  877: {364: [0], 368: [0]},
#  878: {364: [0], 369: [0]},
#  879: {365: [0], 366: [0]},
#  880: {365: [0], 367: [0]},
#  881: {365: [0], 368: [0]},
#  882: {365: [0], 369: [0]},
#  883: {366: [0], 367: [0]},
#  884: {366: [0], 368: [0]},
#  885: {366: [0], 369: [0]},
#  886: {367: [0], 368: [0]},
#  887: {367: [0], 369: [0]},
#  888: {368: [0], 369: [0]},
#  889: {371: [1],
#   372: [1],
#   373: [1],
#   374: [1],
#   375: [1],
#   376: [1],
#   377: [1],
#   378: [1],
#   379: [1]},
#  890: {371: [0], 372: [0]},
#  891: {371: [0], 373: [0]},
#  892: {371: [0], 374: [0]},
#  893: {371: [0], 375: [0]},
#  894: {371: [0], 376: [0]},
#  895: {371: [0], 377: [0]},
#  896: {371: [0], 378: [0]},
#  897: {371: [0], 379: [0]},
#  898: {372: [0], 373: [0]},
#  899: {372: [0], 374: [0]},
#  900: {372: [0], 375: [0]},
#  901: {372: [0], 376: [0]},
#  902: {372: [0], 377: [0]},
#  903: {372: [0], 378: [0]},
#  904: {372: [0], 379: [0]},
#  905: {373: [0], 374: [0]},
#  906: {373: [0], 375: [0]},
#  907: {373: [0], 376: [0]},
#  908: {373: [0], 377: [0]},
#  909: {373: [0], 378: [0]},
#  910: {373: [0], 379: [0]},
#  911: {374: [0], 375: [0]},
#  912: {374: [0], 376: [0]},
#  913: {374: [0], 377: [0]},
#  914: {374: [0], 378: [0]},
#  915: {374: [0], 379: [0]},
#  916: {375: [0], 376: [0]},
#  917: {375: [0], 377: [0]},
#  918: {375: [0], 378: [0]},
#  919: {375: [0], 379: [0]},
#  920: {376: [0], 377: [0]},
#  921: {376: [0], 378: [0]},
#  922: {376: [0], 379: [0]},
#  923: {377: [0], 378: [0]},
#  924: {377: [0], 379: [0]},
#  925: {378: [0], 379: [0]},
#  926: {381: [1],
#   382: [1],
#   383: [1],
#   384: [1],
#   385: [1],
#   386: [1],
#   387: [1],
#   388: [1],
#   389: [1]},
#  927: {381: [0], 382: [0]},
#  928: {381: [0], 383: [0]},
#  929: {381: [0], 384: [0]},
#  930: {381: [0], 385: [0]},
#  931: {381: [0], 386: [0]},
#  932: {381: [0], 387: [0]},
#  933: {381: [0], 388: [0]},
#  934: {381: [0], 389: [0]},
#  935: {382: [0], 383: [0]},
#  936: {382: [0], 384: [0]},
#  937: {382: [0], 385: [0]},
#  938: {382: [0], 386: [0]},
#  939: {382: [0], 387: [0]},
#  940: {382: [0], 388: [0]},
#  941: {382: [0], 389: [0]},
#  942: {383: [0], 384: [0]},
#  943: {383: [0], 385: [0]},
#  944: {383: [0], 386: [0]},
#  945: {383: [0], 387: [0]},
#  946: {383: [0], 388: [0]},
#  947: {383: [0], 389: [0]},
#  948: {384: [0], 385: [0]},
#  949: {384: [0], 386: [0]},
#  950: {384: [0], 387: [0]},
#  951: {384: [0], 388: [0]},
#  952: {384: [0], 389: [0]},
#  953: {385: [0], 386: [0]},
#  954: {385: [0], 387: [0]},
#  955: {385: [0], 388: [0]},
#  956: {385: [0], 389: [0]},
#  957: {386: [0], 387: [0]},
#  958: {386: [0], 388: [0]},
#  959: {386: [0], 389: [0]},
#  960: {387: [0], 388: [0]},
#  961: {387: [0], 389: [0]},
#  962: {388: [0], 389: [0]},
#  963: {391: [1],
#   392: [1],
#   393: [1],
#   394: [1],
#   395: [1],
#   396: [1],
#   397: [1],
#   398: [1],
#   399: [1]},
#  964: {391: [0], 392: [0]},
#  965: {391: [0], 393: [0]},
#  966: {391: [0], 394: [0]},
#  967: {391: [0], 395: [0]},
#  968: {391: [0], 396: [0]},
#  969: {391: [0], 397: [0]},
#  970: {391: [0], 398: [0]},
#  971: {391: [0], 399: [0]},
#  972: {392: [0], 393: [0]},
#  973: {392: [0], 394: [0]},
#  974: {392: [0], 395: [0]},
#  975: {392: [0], 396: [0]},
#  976: {392: [0], 397: [0]},
#  977: {392: [0], 398: [0]},
#  978: {392: [0], 399: [0]},
#  979: {393: [0], 394: [0]},
#  980: {393: [0], 395: [0]},
#  981: {393: [0], 396: [0]},
#  982: {393: [0], 397: [0]},
#  983: {393: [0], 398: [0]},
#  984: {393: [0], 399: [0]},
#  985: {394: [0], 395: [0]},
#  986: {394: [0], 396: [0]},
#  987: {394: [0], 397: [0]},
#  988: {394: [0], 398: [0]},
#  989: {394: [0], 399: [0]},
#  990: {395: [0], 396: [0]},
#  991: {395: [0], 397: [0]},
#  992: {395: [0], 398: [0]},
#  993: {395: [0], 399: [0]},
#  994: {396: [0], 397: [0]},
#  995: {396: [0], 398: [0]},
#  996: {396: [0], 399: [0]},
#  997: {397: [0], 398: [0]},
#  998: {397: [0], 399: [0]},
#  999: {398: [0], 399: [0]},
#  1000: {411: [1],
#   412: [1],
#   413: [1],
#   414: [1],
#   415: [1],
#   416: [1],
#   417: [1],
#   418: [1],
#   419: [1]},
#  ...}

# %%
def remove_tautology(clauses, variables):
    # for each variable
    for var_name, var_idx in variables.items():
        # check if variable has double occurance in any clause
        duplicates = set([x for x in var_idx[1:] if var_idx[1:].count(x) > 1])
        #if not, continue
        if len(duplicates) == 0:
            continue
        #for each clause where variable occurs twice
        for idx in duplicates:
            is_break = False
            #for each literal of that variable in the clause
            for literal_i in  clauses[idx][var_name]:
                #double_break
                if is_break:
                    break
                #for every other literal
                for literal_j in clauses[idx][var_name]:
                    #if there is a tautology
                    if literal_i != literal_j:
                        #remove this clause
                        del clauses[idx]
                        #removing index of this clause from variables
                        for var_name_2, var_idx_2 in variables.items():
                            new_var = [var_idx_2[0]] + [x for x in var_idx_2[1:] if x != idx]
                            variables[var_name_2] = new_var
                        
                        #double break
                        is_break = True
                        break
    return clauses, variables
            #print(idx,var_name)
            #print(clauses[idx][var_name])

test_var = {1:[None, 0], 2: [None, 0,1,1], 3:[None, 0,1], 4:[None, 1,2,2] }
test_clauses = {0:{1:[0],2:[1],3:[0]},1:{4:[1],2:[0,1], 3:[1]},2:{4:[0,1]}}
remove_tautology(test_clauses, test_var)
# Out:
# ({0: {1: [0], 2: [1], 3: [0]}},
#  {1: [None, 0], 2: [None, 0], 3: [None, 0], 4: [None]})

# %%
# remove unit clause

def remove_unit(var):
    idx = variables[var]
    sent = idx[0]
    idx = idx[1:]
    changed_var = []
    for n in idx:
        cl = clauses[n]
        if sent and cl[var]==0 and len(clauses[n])==2:
            #set second variable to False
            for x in clauses[n]:
                secndvar = x
            if secndvar == #check if it is already assigned:
                raise #error msg for inconsistency
                break
            variables[secndvar] #how can we set it to False???
            #track variable to run this again on it
            changed_var.append(secndvar)
            del clauses[n]
            
        if sent and cl[var]==1:
            del clauses[n]
            
        if not sent and cl[var]==0:
            del clauses[n]
        
        if not sent and cl[var]==1 and len(clauses[n])==2:
            # same as first if statement
            
        if not sent and cl[var]==1 and len(clauses[n])>2:
            cl_sent = False
            for x in cl:
                x_sent = variables[x]
                x_sent = xsent[0]
                if cl[x] == 1 and x_sent or cl[x] == 0 and not x_sent:
                    cl_sent = True
            if cl_sent:
                del clauses[n]
                
        if sent and cl[var]==0 and len(clauses[n])>2:
            cl_sent = False
            for x in cl:
                x_sent = variables[x]
                x_sent = xsent[0]
                if cl[x] == 1 and x_sent or cl[x] == 0 and not x_sent:
                    cl_sent = True
            if cl_sent:
                del clauses[n]
# Out:
#   File "<ipython-input-165-0130c5ce3123>", line 14
#     if secndvar == #check if it is already assigned:
#                                                     ^
# SyntaxError: invalid syntax

# %%
def delete_clause(idx, clauses, variables, deleted_clauses, i):
    #append the clause to be deleted
    deleted_clauses[i] = {idx: clauses[idx]}
    #remove the clause from mentions in all variables
    for variable in clauses[idx]:
        new_var = [variables[variable][0]] + [x for x in variables[variable][1:] if x!=idx]
        variables[variable] = new_var
    #delete the clause
    del clauses[idx]
    
    return clauses, variables, deleted_clauses, i


def belief_propogation(variable, clauses, variables, deleted_clauses, i):
    truth_value = variables[variable][0]
    
    for clause in variables[variable][1:]:
        print(i,clause, variable, truth_value)
        if truth_value == clauses[clause][variable][0]:
            i+=1
            clauses, variables, deleted_clauses, i = delete_clause(clause, clauses, variables, deleted_clauses, i)
        else:
            del clauses[clause][variable]
    return clauses, variables, deleted_clauses, i
    

def unit_check(clauses, variables, deleted_clauses = {}):
    i = len(deleted_clauses)
    generator = ( (idx, clause) for (idx, clause) in clauses.items() )
    empty = True
    for idx, clause in  generator:
        
        if len(clause) == 1:
            
            variable = list(clause.keys())[0]
            literal = list(clause.values())[0][0]
            
            if literal == 1:
                variables[variable][0] = True
                i+=1
                delete_clause(idx, clauses, variables, deleted_clauses, i)
                belief_propogation(variable, clauses, variables, deleted_clauses, i)
                empty = False
                break
                
            else:
                variables[variable][0] = False
                i+=1
                delete_clause(idx, clauses, variables, deleted_clauses, i)
                belief_propogation(variable, clauses, variables, deleted_clauses, i)
                empty = False
                break
                
    return clauses, variables, deleted_clauses, empty
                
            
test_var = {1:[None, 0, 3], 2: [None, 0,1,1], 3:[None, 0,1], 4:[None, 1,2,2] }
test_clauses = {0:{1:[0],2:[1],3:[0]},1:{4:[1],2:[0,1], 3:[1]},2:{4:[1]}, 3:{1:[0]}}
unit_check(test_clauses, test_var)
# Out:
# 1 1 4 True
# ({0: {1: [0], 2: [1], 3: [0]}, 3: {1: [0]}},
#  {1: [None, 0, 3], 2: [None, 0], 3: [None, 0], 4: [True]},
#  {1: {2: {4: [1]}}, 2: {1: {2: [0, 1], 3: [1], 4: [1]}}},
#  False)

# %%
def check_for_empty_clause(clauses):
    for clause in clauses.values():
        if len(clause) == 0:
            return True
    return False
def check_emptiness(clauses):
    if len(clauses) == 0:
        return True
    else:
        return False

# %%
#remove tautology
clauses, variables = remove_tautology(clauses, variables)
def dpll(clauses, variables, deleted_clauses = {}):
    while True:
        #simplification round
        
        while True:
            #simplify
            #i_begin
            #i_end
            clauses, variables, deleted_clauses, empty = unit_check(clauses, variables, deleted_clauses)
            if empty:
                break
                
        if check_for_empty_clause(clauses):
            print("False")
            return False
            break
        if check_emptiness(clauses):
            print("True")
            return variables
            break
        #split randomely for now
        print("GOT HERE")
        variable = np.random.choice([key for (key, value) in variables.items() if value[0]==None])
        
        variables[variable][0] = True
        is_true = dpll(clauses, variables, deleted_clauses)
        if is_true:
            return "SAT", variables
        else:
            variables[variable][0] = False
            dpll(clauses, variables, deleted_clauses)
            
       
    print("NOT SAT")
    return False

test_var = {1:[None, 0, 3], 2: [None, 0,1], 3:[None, 0,1], 4:[None, 1,2,2] }
test_clauses = {0:{1:[0],2:[1],3:[0]},1:{4:[0],2:[0], 3:[1]},2:{4:[1]}, 3:{1:[0]}}
#test_clauses, test_var = remove_tautology(test_clauses, test_var)
test_clauses, test_var = remove_tautology(test_clauses, test_var)
dpll(test_clauses, test_var)
# Out:
# 1 1 4 True
# 2 0 1 False
# GOT HERE
# GOT HERE
# GOT HERE
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-401-e6bd96109202> in <module>()
#      40 #test_clauses, test_var = remove_tautology(test_clauses, test_var)
#      41 test_clauses, test_var = remove_tautology(test_clauses, test_var)
# ---> 42 dpll(test_clauses, test_var)
#
# <ipython-input-401-e6bd96109202> in dpll(clauses, variables, deleted_clauses)
#      25         variable = np.random.choice([key for (key, value) in variables.items() if value[0]==None])
#      26         variables[variable][0] = True
# ---> 27         is_true = dpll(clauses, variables, deleted_clauses)
#      28         if is_true:
#      29             return "SAT", variables
#
# <ipython-input-401-e6bd96109202> in dpll(clauses, variables, deleted_clauses)
#      25         variable = np.random.choice([key for (key, value) in variables.items() if value[0]==None])
#      26         variables[variable][0] = True
# ---> 27         is_true = dpll(clauses, variables, deleted_clauses)
#      28         if is_true:
#      29             return "SAT", variables
#
# <ipython-input-401-e6bd96109202> in dpll(clauses, variables, deleted_clauses)
#      23         #split randomely for now
#      24         print("GOT HERE")
# ---> 25         variable = np.random.choice([key for (key, value) in variables.items() if value[0]==None])
#      26         variables[variable][0] = True
#      27         is_true = dpll(clauses, variables, deleted_clauses)
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# ValueError: a must be non-empty

# %%
# Out:
# 56
